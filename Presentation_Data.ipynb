# %%
import pandas as pd

# %%
# Store our file paths; read in the specific sheets we want from the files
data_2014_df = pd.read_excel("C:/Users/Matt/Downloads/Project1_Git-er-done/Resources/Chapter2OnlineData_Expanded2015.xlsx", sheet_name = "Figure2.2",skiprows=3)
data_2015_df = pd.read_excel("C:/Users/Matt/Downloads/Project1_Git-er-done/Resources/Online-data-for-chapter-2-whr-2016.xlsx", sheet_name = "Figure2.2")
data_2016_df = pd.read_excel("C:/Users/Matt/Downloads/Project1_Git-er-done/Resources/online-data-chapter-2-whr-2017.xlsx", sheet_name = "Figure2.2")
data_2017_df = pd.read_excel("C:/Users/Matt/Downloads/Project1_Git-er-done/Resources/WHR2018Chapter2OnlineData_2018.xls", sheet_name = "Figure2.2")
data_2017_table = pd.read_excel("C:/Users/Matt/Downloads/Project1_Git-er-done/Resources/WHR2018Chapter2OnlineData_2018.xls", sheet_name = "Table2.1")

# %%
# Rename our columns to avoid buttfuckery
renamed_2014_df = data_2014_df.rename(columns={"country":"Country", "Explained by: Log GDP per capita":"Explained by: GDP per capita", "Dystopia + residual":"Dystopia Residual"})
renamed_2015_df = data_2015_df.rename(columns={"country":"Country", "Dystopia (2.33) + residual":"Dystopia Residual"})
renamed_2016_df = data_2016_df.rename(columns={"country":"Country", "Dystopia (1.85) + residual":"Dystopia Residual"})
renamed_2017_df = data_2017_df.rename(columns={"country":"Country", "Dystopia (1.92) + residual":"Dystopia Residual"})

# %%
#Drop unneeded columns from 2014 data
renamed_2014_df.columns.to_series()["Trust in national government":"Most people can be trusted, WVS round 2010-2014"]
renamed_2014_df.drop(renamed_2014_df.columns.to_series()["Trust in national government":"Most people can be trusted, WVS round 2010-2014"], axis=1, inplace=True)

# %%
#Continue dropping unneeded columns from 2014 data
renamed_2014_df.drop(renamed_2014_df.columns[0], axis=1, inplace=True)
renamed_2014_df.drop(renamed_2014_df.columns[1:11], axis=1, inplace=True)
renamed_2014_df.head()
# Out:
#        Country  Dystopia Residual  Explained by: GDP per capita  \
# 0  Switzerland           2.517383                      1.396505
# 1      Iceland           2.702013                      1.302324
# 2      Denmark           2.492042                      1.325478
# 3       Norway           2.465312                      1.458997
# 4       Canada           2.451756                      1.326292
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.349505                               0.941432
# 1                      1.402231                               0.947844
# 2                      1.360581                               0.874641
# 3                      1.330955                               0.885209
# 4                      1.322608                               0.905631
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.665573                  0.296775
# ...

# %%
#Drop unneeded columns from 2015 data
renamed_2015_df.drop(renamed_2015_df.columns[12], axis=1, inplace=True)
renamed_2015_df.drop(renamed_2015_df.columns[11], axis=1, inplace=True)
renamed_2015_df.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low  \
# 0      Denmark            7.526      7.591507     7.460493
# 1  Switzerland            7.509      7.589791     7.428208
# 2      Iceland            7.501      7.669368     7.332632
# 3       Norway            7.498      7.574923     7.421077
# 4      Finland            7.413      7.474935     7.351065
#
#    Explained by: GDP per capita  Explained by: Social support  \
# 0                      1.441784                      1.163745
# 1                      1.527334                      1.145236
# 2                      1.426655                      1.183259
# 3                      1.577440                      1.126896
# 4                      1.405979                      1.134640
#
#    Explained by: Healthy life expectancy  \
# 0                               0.795040
# 1                               0.863029
# 2                               0.867333
# 3                               0.795789
# ...

# %%
# There's loads of columns we don't need in the 2017 data. Create a series of them.
renamed_2017_df.columns.to_series()["Unnamed: 11":"Unnamed: 23"]
# Out:
# Unnamed: 11    Unnamed: 11
# Unnamed: 12    Unnamed: 12
# Unnamed: 13    Unnamed: 13
# Unnamed: 14    Unnamed: 14
# Unnamed: 15    Unnamed: 15
# Unnamed: 16    Unnamed: 16
# Unnamed: 17    Unnamed: 17
# Unnamed: 18    Unnamed: 18
# Unnamed: 19    Unnamed: 19
# Unnamed: 20    Unnamed: 20
# Unnamed: 21    Unnamed: 21
# Unnamed: 22    Unnamed: 22
# Unnamed: 23    Unnamed: 23
# dtype: object

# %%
renamed_2017_df.drop(renamed_2017_df.columns.to_series()["Unnamed: 11":"Unnamed: 23"], axis=1, inplace=True)
renamed_2017_df
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                     Finland           7.6321      7.694913     7.569287
# 1                      Norway           7.5937      7.657077     7.530323
# 2                     Denmark           7.5553      7.623292     7.487309
# 3                     Iceland           7.4952      7.592534     7.397867
# 4                 Switzerland           7.4873      7.569994     7.404606
# 5                 Netherlands           7.4413      7.498353     7.384247
# 6                      Canada           7.3285      7.420735     7.236264
# 7                 New Zealand           7.3238      7.400652     7.246948
# 8                      Sweden           7.3145      7.388290     7.240710
# 9                   Australia           7.2721      7.358463     7.185737
# 10                     Israel           7.1900      7.256923     7.123078
# 11                    Austria           7.1394      7.209448     7.069352
# ...

# %%
#Display corrected dataframes
renamed_2014_df
# Out:
#                       Country  Dystopia Residual  \
# 0                 Switzerland           2.517383
# 1                     Iceland           2.702013
# 2                     Denmark           2.492042
# 3                      Norway           2.465312
# 4                      Canada           2.451756
# 5                     Finland           2.619551
# 6                 Netherlands           2.465703
# 7                      Sweden           2.371191
# 8                 New Zealand           2.264252
# 9                   Australia           2.266460
# 10                     Israel           3.088542
# 11                 Costa Rica           3.177276
# 12                    Austria           2.533203
# 13                     Mexico           3.602143
# 14              United States           2.510109
# 15                     Brazil           3.260014
# 16                 Luxembourg           1.969613
# 17                    Ireland           1.975696
# ...

# %%
renamed_2015_df
# Out:
#                   Country  Happiness score  Whisker-high  Whisker-low  \
# 0                 Denmark            7.526      7.591507     7.460493
# 1             Switzerland            7.509      7.589791     7.428208
# 2                 Iceland            7.501      7.669368     7.332632
# 3                  Norway            7.498      7.574923     7.421077
# 4                 Finland            7.413      7.474935     7.351065
# 5                  Canada            7.404      7.472630     7.335370
# 6             Netherlands            7.339      7.393850     7.284150
# 7             New Zealand            7.334      7.403604     7.264396
# 8               Australia            7.313      7.385071     7.240929
# 9                  Sweden            7.291      7.354515     7.227484
# 10                 Israel            7.267      7.335185     7.198815
# 11                Austria            7.119      7.192645     7.045355
# ...

# %%
renamed_2016_df
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                      Norway            7.537      7.594445     7.479556
# 1                     Denmark            7.522      7.581728     7.462272
# 2                     Iceland            7.504      7.622030     7.385970
# 3                 Switzerland            7.494      7.561772     7.426227
# 4                     Finland            7.469      7.527542     7.410458
# 5                 Netherlands            7.377      7.427426     7.326574
# 6                      Canada            7.316      7.384403     7.247597
# 7                 New Zealand            7.314      7.379510     7.248490
# 8                      Sweden            7.284      7.344095     7.223905
# 9                   Australia            7.284      7.356651     7.211349
# 10                     Israel            7.213      7.279853     7.146146
# 11                 Costa Rica            7.079      7.168112     6.989888
# ...

# %%
renamed_2017_df
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                     Finland           7.6321      7.694913     7.569287
# 1                      Norway           7.5937      7.657077     7.530323
# 2                     Denmark           7.5553      7.623292     7.487309
# 3                     Iceland           7.4952      7.592534     7.397867
# 4                 Switzerland           7.4873      7.569994     7.404606
# 5                 Netherlands           7.4413      7.498353     7.384247
# 6                      Canada           7.3285      7.420735     7.236264
# 7                 New Zealand           7.3238      7.400652     7.246948
# 8                      Sweden           7.3145      7.388290     7.240710
# 9                   Australia           7.2721      7.358463     7.185737
# 10                     Israel           7.1900      7.256923     7.123078
# 11                    Austria           7.1394      7.209448     7.069352
# ...

# %%
#Add years to make final dataframe readable
renamed_2014_df["Year"] = 2014
renamed_2015_df["Year"] = 2015
renamed_2016_df["Year"] = 2016
renamed_2017_df["Year"] = 2017

# %%
# Determine happiness score for 2014
renamed_2014_df["Happiness score"] = renamed_2014_df["Explained by: GDP per capita"]+\
renamed_2014_df["Explained by: Social support"]+\
renamed_2014_df["Explained by: Healthy life expectancy"]+\
renamed_2014_df["Explained by: Freedom to make life choices"]+\
renamed_2014_df["Explained by: Generosity"]+\
renamed_2014_df["Explained by: Perceptions of corruption"]+\
renamed_2014_df["Dystopia Residual"]
renamed_2014_df
# Out:
#                       Country  Dystopia Residual  \
# 0                 Switzerland           2.517383
# 1                     Iceland           2.702013
# 2                     Denmark           2.492042
# 3                      Norway           2.465312
# 4                      Canada           2.451756
# 5                     Finland           2.619551
# 6                 Netherlands           2.465703
# 7                      Sweden           2.371191
# 8                 New Zealand           2.264252
# 9                   Australia           2.266460
# 10                     Israel           3.088542
# 11                 Costa Rica           3.177276
# 12                    Austria           2.533203
# 13                     Mexico           3.602143
# 14              United States           2.510109
# 15                     Brazil           3.260014
# 16                 Luxembourg           1.969613
# 17                    Ireland           1.975696
# ...

# %%
renamed_2017 = renamed_2017_df[renamed_2017_df.Year>=2016]
renamed_2017
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                     Finland           7.6321      7.694913     7.569287
# 1                      Norway           7.5937      7.657077     7.530323
# 2                     Denmark           7.5553      7.623292     7.487309
# 3                     Iceland           7.4952      7.592534     7.397867
# 4                 Switzerland           7.4873      7.569994     7.404606
# 5                 Netherlands           7.4413      7.498353     7.384247
# 6                      Canada           7.3285      7.420735     7.236264
# 7                 New Zealand           7.3238      7.400652     7.246948
# 8                      Sweden           7.3145      7.388290     7.240710
# 9                   Australia           7.2721      7.358463     7.185737
# 10                     Israel           7.1900      7.256923     7.123078
# 11                    Austria           7.1394      7.209448     7.069352
# ...

# %%
#Concatenate!
happiness_df = [renamed_2014_df,renamed_2015_df,renamed_2016_df,renamed_2017_df]
final_df=pd.concat(happiness_df)
final_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#                       Country  Dystopia Residual  \
# 0                 Switzerland           2.517383
# 1                     Iceland           2.702013
# 2                     Denmark           2.492042
# 3                      Norway           2.465312
# 4                      Canada           2.451756
# 5                     Finland           2.619551
# 6                 Netherlands           2.465703
# 7                      Sweden           2.371191
# 8                 New Zealand           2.264252
# 9                   Australia           2.266460
# ...
